# %%
import pandas as pd
import folium
from folium.plugins import HeatMap
from collections import Counter
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import spacy
import time
from tqdm import tqdm

# %%
# Load NLP model
nlp = spacy.load("en_core_web_sm")
geolocator = Nominatim(user_agent="crisis_mapper")

# %%
# Load your dataset
df = pd.read_csv("classified_mental_health_tweets.csv")  # Should include a 'text' column and 'risk_level'

# %%
df
# Out:
#                 post_id                  timestamp  \
# 0   1907753011637592104  2025-04-03 11:12:16+00:00
# 1   1907753010643804454  2025-04-03 11:12:16+00:00
# 2   1907753009184125288  2025-04-03 11:12:16+00:00
# 3   1907753006021439540  2025-04-03 11:12:15+00:00
# 4   1907753004612153744  2025-04-03 11:12:15+00:00
# 5   1907753001810284898  2025-04-03 11:12:14+00:00
# 6   1907753000816333291  2025-04-03 11:12:14+00:00
# 7   1907753000782766323  2025-04-03 11:12:14+00:00
# 8   1907752990280171651  2025-04-03 11:12:11+00:00
# 9   1907752989844033768  2025-04-03 11:12:11+00:00
# 10  1907752989260939665  2025-04-03 11:12:11+00:00
# 11  1907752988925374712  2025-04-03 11:12:11+00:00
# 12  1907752987159642301  2025-04-03 11:12:11+00:00
# 13  1907752986547232882  2025-04-03 11:12:10+00:00
# 14  1907752984936640658  2025-04-03 11:12:10+00:00
# 15  1907752984626254087  2025-04-03 11:12:10+00:00
# 16  1907752982806159378  2025-04-03 11:12:10+00:00
# 17  1907752981828665501  2025-04-03 11:12:09+00:00
# 18  1907752970470482403  2025-04-03 11:12:07+00:00
# 19  1907752969145114996  2025-04-03 11:12:06+00:00
# 20  1907752969048916388  2025-04-03 11:12:06+00:00
# 21  1907752967249273144  2025-04-03 11:12:06+00:00
# 22  1907752963889639674  2025-04-03 11:12:05+00:00
# 23  1907752961490796822  2025-04-03 11:12:05+00:00
# 24  1907752959045222768  2025-04-03 11:12:04+00:00
# 25  1907752957879193901  2025-04-03 11:12:04+00:00
# 26  1907752957522624736  2025-04-03 11:12:04+00:00
# 27  1907752956855816291  2025-04-03 11:12:03+00:00
# 28  1907752952615547338  2025-04-03 11:12:02+00:00
# 29  1907752949398245828  2025-04-03 11:12:02+00:00
# 30  1907752937171882236  2025-04-03 11:11:59+00:00
# 31  1907752934936322237  2025-04-03 11:11:58+00:00
# 32  1907752929081307576  2025-04-03 11:11:57+00:00
# 33  1907752928989024562  2025-04-03 11:11:57+00:00
# 34  1907752928695165192  2025-04-03 11:11:57+00:00
# 35  1907752928087302269  2025-04-03 11:11:57+00:00
# 36  1907752927206277331  2025-04-03 11:11:56+00:00
# 37  1907752927101329435  2025-04-03 11:11:56+00:00
# 38  1907752922714124697  2025-04-03 11:11:55+00:00
# 39  1907752915470561686  2025-04-03 11:11:54+00:00
#
#                                               content  likes  retweets  \
# 0   another poor man beaten raj thackerays goons s...      0      1302
# 1                    mental health absolutely testing      0       666
# 2   mental health great ima strong christian lovin...      0         0
# 3                       cannot stress enough came 5th      0      7817
# 4   meek helpless spineless response indian govt t...      0        74
# 5   overwhelmed tasks ai help automate routine wor...      0         0
# 6   cant stress enough men men women women denying...      0         0
# 7   thoughts epidemic loneliness anxiety collated ...      0        19
# 8   america help police officer doubt mental healt...      0       107
# 9   kanye west confirms wife bianca censori left p...      0         0
# 10  cannot stress enough fifth best woman country ...      0       228
# 11  headlines reuters world news daily podcast us ...      0         6
# 12  47 yearold dr alhajjar lived rusholme manchest...      0       184
# 13                        nothing stress like failing      0         1
# 14  breaking investigating members congress got ri...      0       105
# 15  cannot stress enough alarming anyone cares due...      0      1347
# 16  simplicity reduces stress泉州乐山绵阳大同南宁台州安全放心进店面选清...      0         0
# 17  top therapists neuroscientists dont treat anxi...      0       196
# 18              youre man 97 stress money job talking      0         5
# 19  kind words pastors discourage patients taking ...      0         3
# 20  wish draw attention recent decision national p...      0        36
# 21                babe u cant pull separation anxiety      0       511
# 22  book leading addiction specialist offers clear...      0         0
# 23  past 2 months devasteting body mental health t...      0       440
# 24                     suicidal want disappear awhile      0       126
# 25  adulting dealing anxiety heartbreaks family is...      0      7403
# 26  born purva ashadha nakshatra past karma unstop...      0         0
# 27  seriously crazy dude yuchen zihao want hu yeta...      0         1
# 28  fasting strongest medicine earth fights inflam...      0      1313
# 29  hi rarely ever id hate bother pls take time re...      0        23
# 30     see lagos traffic mental health citizens craze      0        85
# 31  joe biden sanctioned invasion united states ap...      0     27784
# 32  trump tariffs pile stress ailing world economy...      0         0
# 33    pure shock amp stress hoshis face found born 08      0       827
# 34  tas mental physical health top priority lot pl...      0        42
# 35  humans get stuck trauma wild animals recover n...      0      1268
# 36  angry tariffs giant hit retirement investments...      0         0
# 37         understand congress passive hence suicidal      0         0
# 38  another poor man beaten raj thackerays goons s...      0      1302
# 39  called diversity baby idolo learning iyoo yes ...      0         0
#
#     replies        risk_level Sentiment
# 0         0         High-Risk  Negative
# 1         0       Low Concern   Neutral
# 2         0       Low Concern  Positive
# 3         0       Low Concern  Positive
# 4         0         High-Risk  Negative
# 5         0  Moderate Concern  Positive
# 6         0       Low Concern  Positive
# 7         0       Low Concern  Negative
# 8         0       Low Concern  Positive
# 9         0  Moderate Concern  Negative
# 10        0       Low Concern  Positive
# 11        0  Moderate Concern  Negative
# 12        0       Low Concern   Neutral
# 13        0       Low Concern  Positive
# 14        0  Moderate Concern  Positive
# 15        0       Low Concern  Positive
# 16        0       Low Concern   Neutral
# 17        0       Low Concern  Negative
# 18        0       Low Concern  Negative
# 19        0       Low Concern  Positive
# 20        0         High-Risk  Positive
# 21        0  Moderate Concern  Positive
# 22        0       Low Concern  Negative
# 23        0       Low Concern   Neutral
# 24        0         High-Risk  Negative
# 25        0  Moderate Concern  Negative
# 26        0       Low Concern  Positive
# 27        0       Low Concern  Negative
# 28        0         High-Risk  Positive
# 29        0  Moderate Concern  Positive
# 30        0       Low Concern  Negative
# 31        0         High-Risk  Negative
# 32        0  Moderate Concern  Negative
# 33        0       Low Concern  Negative
# 34        0       Low Concern  Negative
# 35        0       Low Concern  Negative
# 36        0       Low Concern  Negative
# 37        0         High-Risk  Negative
# 38        0         High-Risk  Negative
# 39        0  Moderate Concern  Positive

# %%
# Extract geotagged data if available
geo_data = []

for _, row in df.iterrows():
    if 'latitude' in row and 'longitude' in row and pd.notna(row['latitude']) and pd.notna(row['longitude']):
        geo_data.append((row['latitude'], row['longitude']))

# Extract locations using NLP (for rows without geotag)
def extract_location(text):
    doc = nlp(text)
    for ent in doc.ents:
        if ent.label_ in ["GPE", "LOC"]:
            return ent.text
    return None

# %%
df["extracted_place"] = df["content"].map(extract_location)

# Geocode NLP-extracted places
for place in tqdm(df["extracted_place"].dropna().unique()):
    try:
        location = geolocator.geocode(place)
        if location:
            geo_data.append((location.latitude, location.longitude))
        time.sleep(1)  # avoid rate limit
    except GeocoderTimedOut:
        continue
# Out:
# 100%|██████████| 2/2 [00:02<00:00,  1.42s/it]

# %%
print("Non-null extracted places count:", df["extracted_place"].notna().sum())
print("Unique extracted places:", df["extracted_place"].dropna().unique())
# Out:
# Non-null extracted places count: 2
# Unique extracted places: ['america' 'canada']

# %%
print(df['extracted_place'].value_counts())
# Out:
# extracted_place
# america    1
# canada     1
# Name: count, dtype: int64

# %%
print(f"Number of geotagged entries: {len(geo_data)}")
# Out:
# Number of geotagged entries: 2

# %%
# Generate Heatmap
m = folium.Map(location=[20.59, 78.96], zoom_start=4)  # Default: India
HeatMap(geo_data, radius=12, blur=15).add_to(m)
m.save("crisis_heatmap.html")

# %%
# Count top 5 locations
top_locations = Counter(geo_data).most_common(5)
print("\n📍 Top 5 Crisis Discussion Locations:")
for i, ((lat, lon), count) in enumerate(top_locations, 1):
    print(f"{i}. Lat: {lat:.4f}, Lon: {lon:.4f} — {count} posts")

# Save top locations
top_df = pd.DataFrame([
    {"latitude": lat, "longitude": lon, "count": count}
    for (lat, lon), count in top_locations
])
top_df.to_csv("top_crisis_locations.csv", index=False)
# Out:
# 📍 Top 5 Crisis Discussion Locations:
# 1. Lat: 39.7837, Lon: -100.4459 — 1 posts
# 2. Lat: 61.0667, Lon: -107.9917 — 1 posts
